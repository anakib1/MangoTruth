# %%
import logging
from typing import List

from detectors.data.datasets import (
    DatasetRegistry,
    DatasetInfo,
    get_dataset_info,
    get_datasets_by_category,
    get_recommended_datasets,
    list_available_datasets
)

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
registry = DatasetRegistry(cache_dir="./cache/datasets")

# %%
dataset = registry.load_dataset(
    "xlsum",
    max_samples=100,  # Limit for demo
    shuffle=True,
    seed=42
)
# Out:
# INFO:detectors.data.datasets.registry:Loading dataset: xlsum
# INFO:detectors.data.datasets.loaders.huggingface_loader:Loaded dataset anakib1/mango-truth (config: xlsum)
# INFO:detectors.data.datasets.registry:Limited dataset to 100 samples
# INFO:detectors.data.datasets.registry:Loaded dataset with 100 samples
# INFO:detectors.data.datasets.registry:Labels: ['gpt-4o-mini', 'human']
